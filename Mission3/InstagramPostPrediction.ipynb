# %% [markdown]
# # **WIDHYA Mission 3 :**
# ## **Mission : Instagram Post Reach Prediction**

# %% [markdown]
# ## **Import the necessary libraries**

# %%
# Importing the necessary libraries 
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # **Data Collection and Cleaning**

# %% [markdown]
# ### **Read the dataset and preview it**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/Colab Notebooks/instagram_reach.csv'
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/instagram_reach.csv')

# %%
df
# Out:
#     Unnamed: 0  S.No  ... Time since posted Likes
# 0            0     1  ...          11 hours   139
# 1            1     2  ...           2 hours    23
# 2            2     3  ...           2 hours    25
# 3            3     4  ...           3 hours    49
# 4            4     5  ...           3 hours    30
# ..         ...   ...  ...               ...   ...
# 95           8    19  ...           3 hours    31
# 96           9    21  ...           3 hours    42
# 97          10    22  ...           3 hours    10
# 98          11    24  ...           3 hours   222
# 99          12    25  ...           3 hours   109
#
# [100 rows x 8 columns]

# %%
df.head()  ##Prints the top 5 rows of data
# Out:
#    Unnamed: 0  S.No  ... Time since posted Likes
# 0           0     1  ...          11 hours   139
# 1           1     2  ...           2 hours    23
# 2           2     3  ...           2 hours    25
# 3           3     4  ...           3 hours    49
# 4           4     5  ...           3 hours    30
#
# [5 rows x 8 columns]

# %%
df.tail()  ##Prints the bottom 5 rows of data
# Out:
#     Unnamed: 0  S.No  ... Time since posted Likes
# 95           8    19  ...           3 hours    31
# 96           9    21  ...           3 hours    42
# 97          10    22  ...           3 hours    10
# 98          11    24  ...           3 hours   222
# 99          12    25  ...           3 hours   109
#
# [5 rows x 8 columns]

# %% [markdown]
# ## **Information about the dataset**

# %%
df.info()  ## Information about the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         100 non-null    int64
#  1   S.No               100 non-null    int64
#  2   USERNAME           100 non-null    object
#  3   Caption            94 non-null     object
#  4   Followers          100 non-null    int64
#  5   Hashtags           100 non-null    object
#  6   Time since posted  100 non-null    object
#  7   Likes              100 non-null    int64
# dtypes: int64(4), object(4)
# memory usage: 6.4+ KB

# %%
df.describe()  ## Describes the statistics of the dataframe
# Out:
#        Unnamed: 0        S.No   Followers      Likes
# count  100.000000  100.000000   100.00000  100.00000
# mean     8.940000   16.240000   961.96000   46.48000
# std      6.639064    7.384286  1014.62567   55.08698
# min      0.000000    1.000000    11.00000    8.00000
# 25%      4.000000   10.750000   252.75000   19.00000
# 50%      8.000000   16.500000   612.00000   29.00000
# 75%     12.250000   22.250000  1197.00000   46.00000
# max     26.000000   30.000000  4496.00000  349.00000

# %% [markdown]
# ## **Remove the unwanted columns**

# %%
df = df.drop(['S.No','USERNAME','Caption','Hashtags'],axis=1)
df
# Out:
#     Unnamed: 0  Followers Time since posted  Likes
# 0            0       1600          11 hours    139
# 1            1        880           2 hours     23
# 2            2        255           2 hours     25
# 3            3        340           3 hours     49
# 4            4        304           3 hours     30
# ..         ...        ...               ...    ...
# 95           8        614           3 hours     31
# 96           9        450           3 hours     42
# 97          10        182           3 hours     10
# 98          11       2039           3 hours    222
# 99          12        741           3 hours    109
#
# [100 rows x 4 columns]

# %% [markdown]
# ## **Data Preprocessing**

# %%
df['Time']=df['Time since posted'].str.split(" ",n=1,expand=True)[0].astype(int)
df.head()
# Out:
#    Unnamed: 0  Followers Time since posted  Likes  Time
# 0           0       1600          11 hours    139    11
# 1           1        880           2 hours     23     2
# 2           2        255           2 hours     25     2
# 3           3        340           3 hours     49     3
# 4           4        304           3 hours     30     3

# %%
df.drop(['Time since posted'],axis=1)
# Out:
#     Unnamed: 0  Followers  Likes  Time
# 0            0       1600    139    11
# 1            1        880     23     2
# 2            2        255     25     2
# 3            3        340     49     3
# 4            4        304     30     3
# ..         ...        ...    ...   ...
# 95           8        614     31     3
# 96           9        450     42     3
# 97          10        182     10     3
# 98          11       2039    222     3
# 99          12        741    109     3
#
# [100 rows x 4 columns]

# %%
df = df[['Followers','Time','Likes']]
df.head()
# Out:
#    Followers  Time  Likes
# 0       1600    11    139
# 1        880     2     23
# 2        255     2     25
# 3        340     3     49
# 4        304     3     30

# %% [markdown]
# # **Build Your ML Model**

# %% [markdown]
# ## **Dividing and Splitting data into training and test data**

# %%
df1 = df.values
X, y = df1[:,:-1], df1[:,-1]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %% [markdown]
# ## **Feature Scaling**

# %%
scaled_features = StandardScaler().fit_transform(X_train, X_test)

# %% [markdown]
# ## **Model Building**

# %%
l_regre=LinearRegression()
l_regre.fit(X_train,y_train)
print("Training has been completed")
# Out:
# Training has been completed

# %% [markdown]
# ## **Training and Test Score of the Model**

# %%
print('Training Score: ', round(l_regre.score(X_train,y_train)*100,2),'%')
print('Testing Score: ', round(l_regre.score(X_test,y_test)*100,2))
# Out:
# Training Score:  35.83 %
# Testing Score:  61.84

# %% [markdown]
# ## **Prediction on the test set**

# %%
y_predict=l_regre.predict(X_test)

# %% [markdown]
# ## **Calculation Of Accuracy**

# %%
from sklearn import metrics
acc=metrics.r2_score(y_test,y_predict)
print("Accuracy Score of Model: ",round(acc*100,2),'%')
# Out:
# Accuracy Score of Model:  61.84 %

# %% [markdown]
# ## **Evaluation of the Model**

# %%
from sklearn import metrics
print('Mean Absolute Error:',round(metrics.mean_absolute_error(y_test,y_predict),2))
print('Mean Squared Error:',round(metrics.mean_squared_error(y_test,y_predict),2))
print('Root Mean Squared Error:',round(np.sqrt(metrics.mean_squared_error(y_test,y_predict)),2))
print('Explained Variance Score:',round(metrics.explained_variance_score(y_test,y_predict),2))
# Out:
# Mean Absolute Error: 18.5
# Mean Squared Error: 541.01
# Root Mean Squared Error: 23.26
# Explained Variance Score: 0.68

# %% [markdown]
# ### **Prediction Samples**

# %% [markdown]
# Prediction for the post's reach for someone who has 400 followers and after 12 hours

# %%
print(l_regre.predict([[400,12]]))
# Out:
# [128.91940186]

# %% [markdown]
# Prediction for the post's reach for someone who has 300 followers and after 10 hours

# %%
print(l_regre.predict([[300,10]]))
# Out:
# [108.75693473]

# %% [markdown]
# # **Thank You !!**
